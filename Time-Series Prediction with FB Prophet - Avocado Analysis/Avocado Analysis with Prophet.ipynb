# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
from fbprophet import Prophet

# %%
import pandas as pd

# %%
df = pd.read_csv('avocado.csv')

# %%
df.drop(labels=['Unnamed: 0', 'year'], axis=1, inplace=True)

# %%
print(df.region.unique())
# Out:
# ['Albany' 'Atlanta' 'BaltimoreWashington' 'Boise' 'Boston'
#  'BuffaloRochester' 'California' 'Charlotte' 'Chicago' 'CincinnatiDayton'
#  'Columbus' 'DallasFtWorth' 'Denver' 'Detroit' 'GrandRapids' 'GreatLakes'
#  'HarrisburgScranton' 'HartfordSpringfield' 'Houston' 'Indianapolis'
#  'Jacksonville' 'LasVegas' 'LosAngeles' 'Louisville' 'MiamiFtLauderdale'
#  'Midsouth' 'Nashville' 'NewOrleansMobile' 'NewYork' 'Northeast'
#  'NorthernNewEngland' 'Orlando' 'Philadelphia' 'PhoenixTucson'
#  'Pittsburgh' 'Plains' 'Portland' 'RaleighGreensboro' 'RichmondNorfolk'
#  'Roanoke' 'Sacramento' 'SanDiego' 'SanFrancisco' 'Seattle'
#  'SouthCarolina' 'SouthCentral' 'Southeast' 'Spokane' 'StLouis' 'Syracuse'
#  'Tampa' 'TotalUS' 'West' 'WestTexNewMexico']

# %%
totaldf = df[df['region'] == 'TotalUS']

# %%
totaldf.Date.astype('datetime64')
# Out:
# 2652    2015-12-27
# 2653    2015-12-20
# 2654    2015-12-13
# 2655    2015-12-06
# 2656    2015-11-29
# 2657    2015-11-22
# 2658    2015-11-15
# 2659    2015-11-08
# 2660    2015-11-01
# 2661    2015-10-25
# 2662    2015-10-18
# 2663    2015-10-11
# 2664    2015-10-04
# 2665    2015-09-27
# 2666    2015-09-20
# 2667    2015-09-13
# 2668    2015-09-06
# 2669    2015-08-30
# 2670    2015-08-23
# 2671    2015-08-16
# 2672    2015-08-09
# 2673    2015-08-02
# 2674    2015-07-26
# 2675    2015-07-19
# 2676    2015-07-12
# 2677    2015-07-05
# 2678    2015-06-28
# 2679    2015-06-21
# 2680    2015-06-14
# 2681    2015-06-07
#            ...
# 17479   2017-04-30
# 17480   2017-04-23
# 17481   2017-04-16
# 17482   2017-04-09
# 17483   2017-04-02
# 17484   2017-03-26
# 17485   2017-03-19
# 17486   2017-03-12
# 17487   2017-03-05
# 17488   2017-02-26
# 17489   2017-02-19
# 17490   2017-02-12
# 17491   2017-02-05
# 17492   2017-01-29
# 17493   2017-01-22
# 17494   2017-01-15
# 17495   2017-01-08
# 17496   2017-01-01
# 18213   2018-03-25
# 18214   2018-03-18
# 18215   2018-03-11
# 18216   2018-03-04
# 18217   2018-02-25
# 18218   2018-02-18
# 18219   2018-02-11
# 18220   2018-02-04
# 18221   2018-01-28
# 18222   2018-01-21
# 18223   2018-01-14
# 18224   2018-01-07
# Name: Date, Length: 338, dtype: datetime64[ns]

# %%
totaldf = totaldf.drop(columns='region')

# %%
orgdf = totaldf[totaldf['type'] == 'organic']
condf = totaldf[totaldf['type'] == 'conventional']

# %%
orgdf_ready = orgdf[['Date', 'AveragePrice']]

# %%
# Organic avocados:
orgdf_ready.columns = ['ds', 'y']

# %%
orgdf_ready['ds'] = orgdf_ready['ds'].astype('datetime64[ns]')

# %%
orgdf_ready.set_index('ds')
# Out:
# 18214 2018-03-18  1.54
# 18215 2018-03-11  1.52
# 18216 2018-03-04  1.52
# 18217 2018-02-25  1.57
# 18218 2018-02-18  1.52
# 18219 2018-02-11  1.56
# 18220 2018-02-04  1.53
# 18221 2018-01-28  1.61
# 18222 2018-01-21  1.63
# 18223 2018-01-14  1.59
# 18224 2018-01-07  1.51
#
# [169 rows x 2 columns]

# %%
m = Prophet()
m.fit(orgdf_ready)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)

# %%
forecast = m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#             ds      yhat  yhat_lower  yhat_upper
# 529 2019-03-21  1.777671    1.605332    1.949133
# 530 2019-03-22  1.785573    1.593319    1.969293
# 531 2019-03-23  1.793586    1.618886    1.979545
# 532 2019-03-24  1.801608    1.637943    1.974247
# 533 2019-03-25  1.809540    1.632424    1.971754

# %%
fig1 = m.plot(forecast) # Organic Avocado Prices - y=price, ds= time

# %%
# Conventional (Non-organic) Avocados:
condf_ready = condf[['Date', 'AveragePrice']]
condf_ready.columns = ['ds', 'y']

# %%
condf_ready['ds'] = condf_ready['ds'].astype('datetime64[ns]')
condf_ready.set_index('ds')
# Out:
#                y
# ds
# 2015-12-27  0.95
# 2015-12-20  0.98
# 2015-12-13  0.93
# 2015-12-06  0.89
# 2015-11-29  0.99
# 2015-11-22  0.96
# 2015-11-15  0.92
# 2015-11-08  0.97
# 2015-11-01  0.97
# 2015-10-25  1.04
# 2015-10-18  0.99
# 2015-10-11  1.00
# 2015-10-04  1.02
# 2015-09-27  1.03
# 2015-09-20  1.02
# 2015-09-13  1.03
# 2015-09-06  1.02
# 2015-08-30  1.07
# 2015-08-23  1.08
# 2015-08-16  1.05
# 2015-08-09  1.05
# 2015-08-02  1.09
# 2015-07-26  1.07
# 2015-07-19  1.07
# 2015-07-12  1.07
# 2015-07-05  1.04
# 2015-06-28  1.06
# 2015-06-21  1.02
# 2015-06-14  0.98
# 2015-06-07  1.00
# ...          ...
# 2017-04-30  1.18
# 2017-04-23  1.18
# 2017-04-16  1.23
# 2017-04-09  1.21
# 2017-04-02  1.21
# 2017-03-26  1.24
# 2017-03-19  1.25
# 2017-03-12  1.22
# 2017-03-05  1.13
# 2017-02-26  0.99
# 2017-02-19  0.99
# 2017-02-12  0.87
# 2017-02-05  0.77
# 2017-01-29  0.96
# 2017-01-22  0.94
# 2017-01-15  0.98
# 2017-01-08  0.99
# 2017-01-01  0.89
# 2018-03-25  1.03
# 2018-03-18  1.05
# 2018-03-11  1.09
# 2018-03-04  1.07
# 2018-02-25  1.06
# 2018-02-18  1.08
# 2018-02-11  0.97
# 2018-02-04  0.87
# 2018-01-28  1.09
# 2018-01-21  1.08
# 2018-01-14  1.20
# 2018-01-07  1.13
#
# [169 rows x 1 columns]

# %%
n = Prophet()
n.fit(condf_ready)
future_n = n.make_future_dataframe(periods=365)
forecast_n = n.predict(future_n)
forecast_n[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds      yhat  yhat_lower  yhat_upper
# 529 2019-03-21  1.100679    0.967159    1.229495
# 530 2019-03-22  1.101912    0.976090    1.224833
# 531 2019-03-23  1.103614    0.964997    1.234584
# 532 2019-03-24  1.105771    0.973021    1.229279
# 533 2019-03-25  1.108353    0.970949    1.239741

# %%
fig2 = n.plot(forecast_n) # Conventional Avocados y = price, ds = date
